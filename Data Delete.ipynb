# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as img
import cv2
import os
import glob
import shutil

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Github/Art_Captioning/Refining.csv', encoding='cp949')

# %%
df = df.drop_duplicates(subset=["Number"], keep='first')

# %%
df = df.drop(columns=['Unnamed: 0'])
df.head()
# Out:
#    Number                                              image  \
# 0       0    https://www.wga.hu/detail/a/aachen/allegory.jpg
# 1       7    https://www.wga.hu/detail/a/aachen/k_couple.jpg
# 2      22    https://www.wga.hu/detail/a/abadie/sacreco3.jpg
# 3      35    https://www.wga.hu/detail/a/abbate/portrai2.jpg
# 4      63  https://www.wga.hu/detail/a/adam/lambert/selfp...
#
#                                          description                   AUTHOR  \
# 0  ['\r\nThe painting, displaying the characteris...         AACHEN, Hans von
# 1  ['\r\nIn his few genre paintings, such as the ...         AACHEN, Hans von
# 2  ['\r\nThe photo shows the cupola from inside.\...             ABADIE, Paul
# 3  ['\r\nThe portrait depicts a young man with pa...    ABBATE, Niccol? dell'
# 4  ['\r\nIt is the Seine and Marne group for Sain...  ADAM, Lambert-Sigisbert
#
#                                    BORN-DIED                 TITLE       DATE  \
# ...

# %%
df.shape
# Out:
# (2891, 14)

# %%
new_df = pd.DataFrame(columns = df.columns)
new_df
# Out:
# Empty DataFrame
# Columns: [Number, image, description, AUTHOR, BORN-DIED, TITLE, DATE, TECHNIQUE, LOCATION, FORM, TYPE, SCHOOL, TIMEFRAME, removed]
# Index: []

# %%
a = []

# %%
temp = 0
src_dir = '/content/drive/MyDrive/Github/Art_Captioning/small_wga_refined_images'
fin_dir = '/content/drive/MyDrive/Github/Art_Captioning/Complete Refined'

for num, i in df.iterrows():
    if i['Number'] in a:
        continue
    else:
        #new_df.loc[temp] = i
        temp += 1
        if temp%100 == 0: print(temp)
        path = os.path.join(src_dir, str(i['Number']) + '.jpg')
        shutil.copy(path, fin_dir)
        continue
        #pd.concat() 
print(temp)
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2891

# %%
df.to_csv('/content/drive/MyDrive/Github/Art_Captioning/Refining.csv')

# %%
for i in df['Number']:
  print(i)
# Out:
# 0
# 7
# 22
# 35
# 63
# 110
# 113
# 114
# 117
# 127
# 147
# 171
# 172
# 173
# 174
# 175
# 176
# 177
# 178
# 179
# 180
# 182
# 183
# 184
# 185
# 186
# 187
# 188
# 189
# 190
# 192
# 193
# 194
# 198
# 199
# 206
# 208
# 209
# 210
# 211
# 213
# 214
# 215
# 216
# 218
# 219
# 220
# 221
# 222
# 223
# 224
# 225
# 226
# 227
# 228
# 229
# 230
# 231
# 234
# 235
# 239
# 240
# 245
# 246
# 247
# 248
# 255
# 290
# 313
# 329
# 347
# 348
# 349
# 350
# 351
# 352
# 373
# 374
# 387
# 388
# 389
# 429
# 441
# 490
# 499
# 521
# 523
# 524
# 550
# 555
# 557
# 558
# 559
# 564
# 565
# 568
# 576
# 595
# 597
# 616
# 648
# 649
# 655
# 673
# 676
# 680
# 694
# 695
# 697
# 711
# 713
# 725
# 726
# 727
# 728
# 729
# 747
# 757
# 758
# 759
# 764
# 798
# 824
# 834
# 838
# 839
# 857
# 858
# 859
# 860
# 902
# 903
# 904
# 932
# 933
# 947
# 950
# 951
# 961
# 962
# 963
# 964
# 965
# 975
# 976
# 1005
# 1028
# 1029
# 1037
# 1043
# 1105
# 1141
# 1165
# 1191
# 1192
# 1193
# 1195
# 1234
# 1244
# 1250
# 1256
# 1260
# 1263
# 1274
# ...
