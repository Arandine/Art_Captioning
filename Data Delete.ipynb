# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as img
import cv2
import os
import glob
import shutil

# %%
df = pd.read_csv('/home/hyunwook/Desktop/Python/Art Project - Captioning/small_wga_dataset_unrefined.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                              image  \
# 0          22    https://www.wga.hu/detail/a/abadie/sacreco3.jpg
# 1          51  https://www.wga.hu/detail/a/abildgaa/culmingh.jpg
# 2         206  https://www.wga.hu/detail/a/agostin/1rimini/5z...
# 3         208  https://www.wga.hu/detail/a/agostin/1rimini/5z...
# 4         213  https://www.wga.hu/detail/a/agostin/1rimini/5z...
#
#                                          description               AUTHOR  \
# 0  ['\r\nThe photo shows the cupola from inside.\...         ABADIE, Paul
# 1  ['\r\nThe subject is taken from the Songs of O...  ABILDGAARD, Nicolai
# 2  ['\r\nThe picture shows the relief depicting S...   AGOSTINO DI DUCCIO
# 3  ['\r\nThe picture shows the relief depicting M...   AGOSTINO DI DUCCIO
# 4  ['\r\nThe picture shows the sign of Libra.\r\n...   AGOSTINO DI DUCCIO
#
#                                      BORN-DIED  \
# 0            (b. 1812, Paris, d. 1884, Chatou)
# ...

# %%
new_df = pd.DataFrame(columns = df.columns)
new_df
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, image, description, AUTHOR, BORN-DIED, TITLE, DATE, TECHNIQUE, LOCATION, FORM, TYPE, SCHOOL, TIMEFRAME, removed]
# Index: []

# %%
a = input()
a = a.split(' ')
a = [int(i) for i in a]
temp = 0
src_dir = '/home/hyunwook/Desktop/Python/Art Project - Captioning/small_wga_unrefined_images/'
fin_dir = '/home/hyunwook/Desktop/Python/Art Project - Captioning/small_wga_refined_images/'

for num, i in df.iterrows():
    if i['Unnamed: 0'] in a:
        continue
    else:
        new_df.loc[temp] = i
        temp += 1
        path = os.path.join(src_dir, str(i['Unnamed: 0']) + '.jpg')
        shutil.copy(path, fin_dir)
        continue
        #pd.concat()

# %%
new_df.head()
# Out:
#   Unnamed: 0                                              image  \
# 0         22    https://www.wga.hu/detail/a/abadie/sacreco3.jpg
# 1        206  https://www.wga.hu/detail/a/agostin/1rimini/5z...
# 2        208  https://www.wga.hu/detail/a/agostin/1rimini/5z...
# 3        213  https://www.wga.hu/detail/a/agostin/1rimini/5z...
# 4        214  https://www.wga.hu/detail/a/agostin/1rimini/5z...
#
#                                          description              AUTHOR  \
# 0  ['\r\nThe photo shows the cupola from inside.\...        ABADIE, Paul
# 1  ['\r\nThe picture shows the relief depicting S...  AGOSTINO DI DUCCIO
# 2  ['\r\nThe picture shows the relief depicting M...  AGOSTINO DI DUCCIO
# 3  ['\r\nThe picture shows the sign of Libra.\r\n...  AGOSTINO DI DUCCIO
# 4  ['\r\nThe picture shows the sign of Sagittariu...  AGOSTINO DI DUCCIO
#
#                               BORN-DIED                          TITLE  \
# ...
